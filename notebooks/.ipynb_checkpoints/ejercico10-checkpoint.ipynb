# %%
import sys
sys.path.insert(0, '../src')
from ejercicio10 import puntaje_ronda, ganador_ronda, tabla_posiciones





rounds = [
      {
          'theme': 'Entrada',
          'scores': {
              'Valentina': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
              'Mateo': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
              'Camila': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
              'Santiago': {'judge_1': 6, 'judge_2': 7, 'judge_3': 6},
              'Lucía': {'judge_1': 8, 'judge_2': 8, 'judge_3': 8},
          }
      },
      {
          'theme': 'Plato principal',
          'scores': {
              'Valentina': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
              'Mateo': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
              'Camila': {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
              'Santiago': {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
              'Lucía': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
          }
      },
      {
          'theme': 'Postre',
          'scores': {
              'Valentina': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
              'Mateo': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
              'Camila': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
              'Santiago': {'judge_1': 7, 'judge_2': 7, 'judge_3': 6},
              'Lucía': {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
          }
      },
      {
          'theme': 'Cocina internacional',
          'scores': {
              'Valentina': {'judge_1': 8, 'judge_2': 9, 'judge_3': 9},
              'Mateo': {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
              'Camila': {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
              'Santiago': {'judge_1': 8, 'judge_2': 9, 'judge_3': 7},
              'Lucía': {'judge_1': 7, 'judge_2': 7, 'judge_3': 8},
          }
      },
      {
          'theme': 'Final libre',
          'scores': {
              'Valentina': {'judge_1': 9, 'judge_2': 8, 'judge_3': 9},
              'Mateo': {'judge_1': 8, 'judge_2': 9, 'judge_3': 8},
              'Camila': {'judge_1': 7, 'judge_2': 7, 'judge_3': 7},
              'Santiago': {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
              'Lucía': {'judge_1': 8, 'judge_2': 8, 'judge_3': 7},
          }
      }
  ]
puntaje_total = {}
rondas_ganadas = {}
mejor_ronda = {}
puntajes_por_ronda = {}


for nombre in rounds[0]["scores"]: #recorro los nombres de la primer ronda
    puntaje_total[nombre] = 0
    rondas_ganadas[nombre] = 0
    mejor_ronda[nombre] = 0
    puntajes_por_ronda[nombre] = [] # una lista vacia para ir agregando
    
numero = 1
for ronda in rounds: # recorro cada ronda 
    tema = ronda["theme"] 
    scores = ronda["scores"]
    puntajes_ronda_actual = {} # guardo el puntaje de esa ronda 

    for nombre in scores:
        puntaje = puntaje_ronda(scores[nombre]) # sumo en una funcion los 3 jueces 
        puntajes_ronda_actual[nombre] = puntaje
        puntaje_total[nombre] += puntaje 
        puntajes_por_ronda[nombre].append(puntaje)
        if puntaje > mejor_ronda[nombre]: #actualizo su mejor ronda
            mejor_ronda[nombre] = puntaje 
    ganador, pts = ganador_ronda(scores)
    rondas_ganadas[ganador] += 1

    #muestro la ronda 
    print(f"Ronda {numero} - {tema}: ")
    print(f" Gandador: {ganador} ({pts} pts)")

    # tabla de posiscion 
    ordenados = tabla_posiciones (puntaje_total, rondas_ganadas)
    print(f" {"Cocinero":<15}{"Puntaje":>10}")
    print(f" {"-" * 50}")
    for nombre in ordenados:
        print(f" {nombre:<10}{puntaje_total[nombre]:>10}")

    numero += 1 


print("Tabla de posiciones final: ")
print(f"{"Cocinero":<15}{"Puntaje":>10}{"Rondas ganadas":>17}{"Mejor ronda":>14}{"Promedio":>12}")
print("-" * 70)

nombres_final = tabla_posiciones(puntaje_total, rondas_ganadas) #ordeno por puntaje total 
total_rondas = len(rounds)

for nombre in nombres_final:
    promedio = puntaje_total[nombre] / total_rondas 

    print(f"{nombre:<15}{puntaje_total[nombre]:>10}{rondas_ganadas[nombre]:>17}{mejor_ronda[nombre]:>14}{promedio:>12.1f}")
print ("-" * 70)
# Out:
# Ronda 1 - Entrada:
#  Gandador: Camila (26 pts)
#  Cocinero          Puntaje
#  --------------------------------------------------
#  Camila            26
#  Valentina         24
#  Lucía             24
#  Mateo             22
#  Santiago          19
# Ronda 2 - Plato principal:
#  Gandador: Valentina (26 pts)
#  Cocinero          Puntaje
#  --------------------------------------------------
#  Valentina         50
#  Mateo             46
#  Camila            46
#  Lucía             46
#  Santiago          44
# Ronda 3 - Postre:
#  Gandador: Lucía (27 pts)
#  Cocinero          Puntaje
#  --------------------------------------------------
#  Lucía             73
#  Mateo             72
#  Valentina         72
#  Camila            70
#  Santiago          64
# Ronda 4 - Cocina internacional:
#  Gandador: Valentina (26 pts)
#  Cocinero          Puntaje
#  --------------------------------------------------
#  Valentina         98
#  Camila            95
#  Lucía             95
#  Mateo             92
#  Santiago          88
# Ronda 5 - Final libre:
#  Gandador: Santiago (27 pts)
#  Cocinero          Puntaje
#  --------------------------------------------------
#  Valentina        124
#  Lucía            118
#  Mateo            117
#  Camila           116
#  Santiago         115
# Tabla de posiciones final:
# Cocinero          Puntaje   Rondas ganadas   Mejor ronda    Promedio
# ----------------------------------------------------------------------
# Valentina             124                2            26        24.8
# Lucía                 118                1            27        23.6
# Mateo                 117                0            26        23.4
# Camila                116                1            26        23.2
# Santiago              115                1            27        23.0
# ----------------------------------------------------------------------
